# %% [markdown]
# # Academic Risk Prediction Project
#
# ## Problem
# We aim to predict academic risk in higher education using Kaggle’s Playground Series S4E6 dataset.
#
# ## Data Sources
# - [Train dataset](https://raw.githubusercontent.com/Arthur-IO/Data-Science-Final-Proj/master/data/train.csv)
# - [Test dataset](https://raw.githubusercontent.com/Arthur-IO/Data-Science-Final-Proj/master/data/test.csv)
# - [Sample submission](https://raw.githubusercontent.com/Arthur-IO/Data-Science-Final-Proj/master/data/sample_submission.csv)
#
# ## Goals
# - Minimize prediction error
# - Compare multiple models
# - Document reproducible pipeline
#
# ## Notebook roadmap
# 1. EDA
# 2. Preprocessing
# 3. Baseline model
# 4. Model experiments
# 5. Hyperparameter tuning
# 6. Evaluation
# 7. Conclusion
